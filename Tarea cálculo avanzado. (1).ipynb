# %% [markdown]
# # Cálculo avanzado : Tarea n°1

# %% [markdown]
# CG es el método iterativo más popular para resolver grandes sistemas de ecuaciones lineales. CG es eficaz para sistemas de la forma:                  Ax = b
#
# dónde A	es un desconocido vector, b un vector conocido, y A una matriz conocida, cuadrada, simétrica, definida positiva (o indefinida positiva).
#
# Comencemos con algunas definiciones y notas sobre notación.
#
# En este caso se utilizarán las mayusculas para denotar matrices, las minúsculas para vectores y las letras griegas para escalares. Podemos saber que A es una matriz nxn y x y b son vectores.

# %% [markdown]
# ![Captura%20de%20pantalla%202021-03-17%20010207.png](attachment:Captura%20de%20pantalla%202021-03-17%20010207.png)

# %%
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools

# %% [markdown]
# Ejemplo en 2D

# %%
A = np.matrix([[3.0, 2.0], [2.0, 6.0]])
b = np.matrix([[2.0], [-8.0]])  
c = 0.0

# %% [markdown]
# forma cuadratica: ![Captura%20de%20pantalla%202021-03-17%20011724.png](attachment:Captura%20de%20pantalla%202021-03-17%20011724.png)

# %% [markdown]
# dónde A es una matriz, X son vectores, y C una constante escalar. Mostraré en breve que si A es simétrico y positivo-definido, f(x) es minimizado por la solución Ax = b.

# %%
def f(x, A, b, c):
    return float(0.5 * x.T * A * x - b.T * x + c)

# %%
def bowl(A, b, c):
    fig = plt.figure(figsize=(10,8))
    qf = fig.gca(projection='3d')
    size = 20
    x1 = list(np.linspace(-6, 6, size))
    x2 = list(np.linspace(-6, 6, size))
    x1, x2 = np.meshgrid(x1, x2)
    zs = np.zeros((size, size))
    for i in range(size):
        for j in range(size):
            x = np.matrix([[x1[i,j]], [x2[i,j]]])
            zs[i,j] = f(x, A, b, c)
    qf.plot_surface(x1, x2, zs, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0)
    fig.show()
    return x1, x2, zs

# %%
x1, x2, zs = bowl(A, b, c)

# %% [markdown]
# ![01.png](attachment:01.png)

# %%
def contoursteps(x1, x2, zs, steps=None):
    fig = plt.figure(figsize=(6,6))
    cp = plt.contour(x1, x2, zs, 10)
    plt.clabel(cp, inline=1, fontsize=10)
    if steps is not None:
        steps = np.matrix(steps)
        plt.plot(steps[:,0], steps[:,1], '-o')
    fig.show()

# %% [markdown]
# Gráfico de contorno de la misma forma cuadrática:

# %%
contoursteps(x1, x2, zs)

# %% [markdown]
# ![02.png](attachment:02.png)

# %% [markdown]
#  Identificar los conceptos del "cálculo avanzado" utilizados por los "gradientes conjugados".
#
#
#
# A partir de lectura realizada pude identificar los siguientes conceptos:
#
# * Forma cuadrática.
# * Derivada parcial.
# * Derivada direccional.
# * Derivada implícita
# * Vector gradiente.
# * Funciones multivariables.
#
#
#
# ¿Que se podrá comprender?
#
# Podremos comprender cómo funciona el método-algoritmo del gradiente conjugado el cual nos permitirá resolver sistemas de ecuaciones lineales multivariables, entre otros.
# También se revisará la implementación de este método con un enfoque hacia la informática utilizando
# el lenguaje de programación Python.
#
# ¿Que no se podrá comprender?
#
# No se podrá comprender lo que no hemos aprendido ni estudiado, pero al tener el tema de gradiente conjugado claro y estudiado a lo largo del curso, ojalá sea muy poco "lo que no se podrá comprender".
#
# ¿Cuales son los aspectos identificables para la profundización?
#
# Los aspectos identificables para la futura profundización de este tema, corresponden a los conceptos
# nombrados anteriormente. En donde a mi parecer, tenemos conceptos claves que debemos manejar para poder
# implementar el método de "Gradientes conjugados" tales como son: **Vector gradiente, derivada parcial y funciones multivariables.**
#
# ¿Cuales son los temas de interes eventualmente relacionados?
#
# Los temas que relacionaremos gracias a la materia de gradiente conjugados, tendra relación al curso de Algebra lineal para la computación ya que involucra matrices, vectores, escalares, entre otros, ademas de ciertas librerias de python relacionadas a graficas como por ejemplo: matplotlib, numpy.
